# %%
import os
import shutil

# %%
import tensorflow as tf

# %%
import tensorflow_hub as hub
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2788\3897380841.py in <module>
# ----> 1 import tensorflow_hub as hub
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_hub\__init__.py in <module>
#      86
#      87
# ---> 88 from tensorflow_hub.estimator import LatestModuleExporter
#      89 from tensorflow_hub.estimator import register_module_for_export
#      90 from tensorflow_hub.feature_column import image_embedding_column
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_hub\estimator.py in <module>
#      60
#      61
# ---> 62 class LatestModuleExporter(tf.compat.v1.estimator.Exporter):
#      63   """Regularly exports registered modules into timestamped directories.
#      64
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in __getattr__(self, item)
#      60
#      61   def __getattr__(self, item):
# ---> 62     module = self._load()
#      63     return getattr(module, item)
#      64
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      43     """Load the module and insert it into the parent's globals."""
#      44     # Import the target module and insert it into the parent's namespace
# ---> 45     module = importlib.import_module(self.__name__)
#      46     self._parent_module_globals[self._local_name] = module
#      47
#
# ~\anaconda3\envs\tensorflow-text\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_estimator\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow_estimator._api.v1 import estimator
#      11
#      12 del _print_function
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_estimator\_api\v1\estimator\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow_estimator._api.v1.estimator import experimental
#      11 from tensorflow_estimator._api.v1.estimator import export
#      12 from tensorflow_estimator._api.v1.estimator import inputs
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_estimator\_api\v1\estimator\experimental\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow_estimator.python.estimator.canned.dnn import dnn_logit_fn_builder
#      11 from tensorflow_estimator.python.estimator.canned.kmeans import KMeansClustering as KMeans
#      12 from tensorflow_estimator.python.estimator.canned.linear import LinearSDCA
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in <module>
#      27 from tensorflow_estimator.python.estimator import estimator
#      28 from tensorflow_estimator.python.estimator.canned import head as head_lib
# ---> 29 from tensorflow_estimator.python.estimator.canned import optimizers
#      30 from tensorflow_estimator.python.estimator.head import head_utils
#      31 from tensorflow_estimator.python.estimator.head import regression_head
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow_estimator\python\estimator\canned\optimizers.py in <module>
#      32
#      33 _OPTIMIZER_CLS_NAMES_V2 = {
# ---> 34     'Adagrad': tf.keras.optimizers.Adagrad,
#      35     'Adam': tf.keras.optimizers.Adam,
#      36     'Ftrl': tf.keras.optimizers.Ftrl,
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in __getattr__(self, item)
#      60
#      61   def __getattr__(self, item):
# ---> 62     module = self._load()
#      63     return getattr(module, item)
#      64
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      43     """Load the module and insert it into the parent's globals."""
#      44     # Import the target module and insert it into the parent's namespace
# ---> 45     module = importlib.import_module(self.__name__)
#      46     self._parent_module_globals[self._local_name] = module
#      47
#
# ~\anaconda3\envs\tensorflow-text\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\layers\__init__.py in <module>
#      21
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\engine\input_layer.py in <module>
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\engine\base_layer.py in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\mixed_precision\loss_scale_optimizer.py in <module>
#      16
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_v2 import optimizer_v2
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizers.py in <module>
#      24 from keras.optimizer_v1 import Optimizer
#      25 from keras.optimizer_v1 import TFOptimizer
# ---> 26 from keras.optimizer_v2 import adadelta as adadelta_v2
#      27 from keras.optimizer_v2 import adagrad as adagrad_v2
#      28 from keras.optimizer_v2 import adam as adam_v2
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizer_v2\adadelta.py in <module>
#      20 import numpy as np
#      21 from keras import backend_config
# ---> 22 from keras.optimizer_v2 import optimizer_v2
#      23 from tensorflow.python.util.tf_export import keras_export
#      24
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in <module>
#      35
#      36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
# ---> 37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      38
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\eager\monitoring.py in __init__(self, name, description, *labels)
#     359     """
#     360     super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
# --> 361                                     len(labels), name, description, *labels)
#     362
#     363   def get_cell(self, *labels):
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\eager\monitoring.py in __init__(self, metric_name, metric_methods, label_length, *args)
#     133           self._metric_name, len(self._metric_methods)))
#     134
# --> 135     self._metric = self._metric_methods[self._label_length].create(*args)
#     136
#     137   def __del__(self):
#
# AlreadyExistsError: Another metric with the same name already exists.

# %%
import tensorflow_text as text
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2788\2835017744.py in <module>
# ----> 1 import tensorflow_text as text
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_text\__init__.py in <module>
#      19 # pylint: disable=wildcard-import
#      20 from tensorflow_text.core.pybinds import tflite_registrar
# ---> 21 from tensorflow_text.python import keras
#      22 from tensorflow_text.python import metrics
#      23 from tensorflow_text.python.ops import *
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_text\python\keras\__init__.py in <module>
#      19
#      20 # pylint: disable=wildcard-import
# ---> 21 from tensorflow_text.python.keras.layers import *
#      22
#      23 # Public symbols in the "tensorflow_text.layers" package.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_text\python\keras\layers\__init__.py in <module>
#      19
#      20 # pylint: disable=wildcard-import
# ---> 21 from tensorflow_text.python.keras.layers.todense import *
#      22
#      23 # Public symbols in the "tensorflow_text.layers" package.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_text\python\keras\layers\todense.py in <module>
#      26
#      27
# ---> 28 class ToDense(tf.keras.layers.Layer):  # pylint: disable=g-classes-have-attributes
#      29   """Layer that makes padding and masking a Composite Tensors effortless.
#      30
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in __getattr__(self, item)
#      60
#      61   def __getattr__(self, item):
# ---> 62     module = self._load()
#      63     return getattr(module, item)
#      64
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      43     """Load the module and insert it into the parent's globals."""
#      44     # Import the target module and insert it into the parent's namespace
# ---> 45     module = importlib.import_module(self.__name__)
#      46     self._parent_module_globals[self._local_name] = module
#      47
#
# ~\anaconda3\envs\tensorflow-text\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\layers\__init__.py in <module>
#      21
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\engine\input_layer.py in <module>
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\engine\base_layer.py in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\mixed_precision\loss_scale_optimizer.py in <module>
#      16
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_v2 import optimizer_v2
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizers.py in <module>
#      24 from keras.optimizer_v1 import Optimizer
#      25 from keras.optimizer_v1 import TFOptimizer
# ---> 26 from keras.optimizer_v2 import adadelta as adadelta_v2
#      27 from keras.optimizer_v2 import adagrad as adagrad_v2
#      28 from keras.optimizer_v2 import adam as adam_v2
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizer_v2\adadelta.py in <module>
#      20 import numpy as np
#      21 from keras import backend_config
# ---> 22 from keras.optimizer_v2 import optimizer_v2
#      23 from tensorflow.python.util.tf_export import keras_export
#      24
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in <module>
#      35
#      36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
# ---> 37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      38
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\eager\monitoring.py in __init__(self, name, description, *labels)
#     359     """
#     360     super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
# --> 361                                     len(labels), name, description, *labels)
#     362
#     363   def get_cell(self, *labels):
#
# ~\anaconda3\envs\tensorflow-text\lib\site-packages\tensorflow\python\eager\monitoring.py in __init__(self, metric_name, metric_methods, label_length, *args)
#     133           self._metric_name, len(self._metric_methods)))
#     134
# --> 135     self._metric = self._metric_methods[self._label_length].create(*args)
#     136
#     137   def __del__(self):
#
# AlreadyExistsError: Another metric with the same name already exists.

# %%
from official.nlp import optimization  # to create AdamW optimizer

import matplotlib.pyplot as plt

tf.get_logger().setLevel('ERROR')
