# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

img = np.asarray(Image.open('./stinkbug.png'))
print(repr(img))
# Out:
# array([[[104, 104, 104],
#         [104, 104, 104],
#         [104, 104, 104],
#         ...,
#         [109, 109, 109],
#         [109, 109, 109],
#         [109, 109, 109]],
#
#        [[105, 105, 105],
#         [105, 105, 105],
#         [105, 105, 105],
#         ...,
#         [109, 109, 109],
#         [109, 109, 109],
#         [109, 109, 109]],
#
#        [[107, 107, 107],
#         [106, 106, 106],
#         [106, 106, 106],
#         ...,
#         [110, 110, 110],
#         [110, 110, 110],
#         [110, 110, 110]],
#
#        ...,
#
#        [[112, 112, 112],
#         [111, 111, 111],
#         [110, 110, 110],
#         ...,
#         [116, 116, 116],
#         [115, 115, 115],
#         [115, 115, 115]],
#
#        [[113, 113, 113],
#         [113, 113, 113],
#         [112, 112, 112],
#         ...,
#         [115, 115, 115],
#         [114, 114, 114],
#         [114, 114, 114]],
#
#        [[113, 113, 113],
#         [115, 115, 115],
#         [115, 115, 115],
#         ...,
#         [114, 114, 114],
#         [114, 114, 114],
#         [113, 113, 113]]], dtype=uint8)

# %%
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img, cmap="hot")

# %%
plt.hist(lum_img.ravel(), bins=range(256), fc='k', ec='k')
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 10))

axs[0].imshow(lum_img)
axs[1].imshow(lum_img, clim=(0, 175))
axs[2].imshow(lum_img, clim=(100, 160))

# %%
img = Image.open('./stinkbug.png')
img.thumbnail((64, 64))  # resizes image in-place
imgplot = plt.imshow(img, interpolation="bicubic")
