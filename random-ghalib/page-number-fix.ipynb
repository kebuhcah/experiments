# %%
import os

# %%
for i, filename in enumerate(sorted(os.listdir('/Users/sunkev/Downloads/olive_tree_large'))):
    print(f'mv {filename} page-{i+1}.jpg')
# Out:
# mv vol-1-page-017.jpg page-1.jpg
# mv vol-1-page-018.jpg page-2.jpg
# mv vol-1-page-019.jpg page-3.jpg
# mv vol-1-page-020.jpg page-4.jpg
# mv vol-1-page-021.jpg page-5.jpg
# mv vol-1-page-022.jpg page-6.jpg
# mv vol-1-page-023.jpg page-7.jpg
# mv vol-1-page-024.jpg page-8.jpg
# mv vol-1-page-025.jpg page-9.jpg
# mv vol-1-page-026.jpg page-10.jpg
# mv vol-1-page-027.jpg page-11.jpg
# mv vol-1-page-028.jpg page-12.jpg
# mv vol-1-page-029.jpg page-13.jpg
# mv vol-1-page-030.jpg page-14.jpg
# mv vol-1-page-031.jpg page-15.jpg
# mv vol-1-page-032.jpg page-16.jpg
# mv vol-1-page-033.jpg page-17.jpg
# mv vol-1-page-034.jpg page-18.jpg
# mv vol-1-page-035.jpg page-19.jpg
# mv vol-1-page-036.jpg page-20.jpg
# mv vol-1-page-037.jpg page-21.jpg
# mv vol-1-page-038.jpg page-22.jpg
# mv vol-1-page-039.jpg page-23.jpg
# mv vol-1-page-040.jpg page-24.jpg
# mv vol-1-page-041.jpg page-25.jpg
# mv vol-1-page-042.jpg page-26.jpg
# mv vol-1-page-043.jpg page-27.jpg
# mv vol-1-page-044.jpg page-28.jpg
# ...
